# %%
# !pip install pandas==0.24
# Out:
# ...
#   Using cached pandas-0.24.0.tar.gz (11.8 MB)
# ...
#   Running setup.py clean for pandas
# Failed to build pandas
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.2
#     Uninstalling pandas-1.4.2:
#       Successfully uninstalled pandas-1.4.2
#     Running setup.py install for pandas: started
#     Running setup.py install for pandas: finished with status 'error'
#   Rolling back uninstall of pandas
#   Moving to c:\users\aditi\anaconda3\lib\site-packages\pandas-1.4.2.dist-info\
#    from C:\Users\aditi\anaconda3\Lib\site-packages\~andas-1.4.2.dist-info
#   Moving to c:\users\aditi\anaconda3\lib\site-packages\pandas\
#    from C:\Users\aditi\anaconda3\Lib\site-packages\~andas
#   ERROR: Command errored out with exit status 1:
# ...

# %%
import pandas as pd
import numpy as np

# %%
OrdersDetails = pd.read_excel('C:/Users/aditi/Downloads/Northwind.xls', sheet_name='Orders Details')
OrdersDetails
# Out:
#       OrderID  ProductID  UnitPrice  Quantity  Discount
# 0       10248         11      14.00        12      0.00
# 1       10248         42       9.80        10      0.00
# 2       10248         72      34.80         5      0.00
# 3       10249         14      18.60         9      0.00
# 4       10249         51      42.40        40      0.00
# ...       ...        ...        ...       ...       ...
# 2150    11077         64      33.25         2      0.03
# 2151    11077         66      17.00         1      0.00
# 2152    11077         73      15.00         2      0.01
# 2153    11077         75       7.75         4      0.00
# 2154    11077         77      13.00         2      0.00
#
# [2155 rows x 5 columns]

# %%
OrdersDetails = OrdersDetails.drop(['UnitPrice','Discount'], axis=1)
OrdersDetails
# Out:
#       OrderID  ProductID  Quantity
# 0       10248         11        12
# 1       10248         42        10
# 2       10248         72         5
# 3       10249         14         9
# 4       10249         51        40
# ...       ...        ...       ...
# 2150    11077         64         2
# 2151    11077         66         1
# 2152    11077         73         2
# 2153    11077         75         4
# 2154    11077         77         2
#
# [2155 rows x 3 columns]

# %%
OrdersDetails1 = OrdersDetails.groupby('OrderID').agg(lambda x: x.tolist())
OrdersDetails1 = OrdersDetails1.drop(['Quantity'], axis=1)
print(OrdersDetails1.shape)
print(OrdersDetails1.to_string())
# Out:
# (830, 1)
#                                                                                               ProductID
# OrderID
# 10248                                                                                      [11, 42, 72]
# 10249                                                                                          [14, 51]
# 10250                                                                                      [41, 51, 65]
# 10251                                                                                      [22, 57, 65]
# 10252                                                                                      [20, 33, 60]
# 10253                                                                                      [31, 39, 49]
# 10254                                                                                      [24, 55, 74]
# 10255                                                                                   [2, 16, 36, 59]
# ...

# %%
# #### Calculate SUPPORT

def calculate_support_01():
    df = pd.DataFrame({"Product":[0]*78,"Quantity":[0]*78, "Support":[0]*78})
    x=[]
    for i in range(0, 77):
        df.iat[i, 0] = i+1
    
    for i in range(0, 77):
        sum = 0
        count = 0
        for j in range(0, 2155):
            if (OrdersDetails.iat[j, 1] == i+1):
                sum = sum + OrdersDetails.iat[j, 2]
                count = count + 1;
        df.iat[i, 1] = sum
        df.iat[i, 2] = count

    print(df.to_string())
    
calculate_support_01()
#for productid in OrdersDetails['ProductID']:
# Out:
#     Product  Quantity  Support
# 0         1       828       38
# 1         2      1057       44
# 2         3       328       12
# 3         4       453       20
# 4         5       298       10
# 5         6       301       12
# 6         7       763       29
# 7         8       372       13
# 8         9        95        5
# 9        10       742       33
# 10       11       706       38
# 11       12       344       14
# 12       13       891       40
# 13       14       404       22
# 14       15       122        6
# 15       16      1158       43
# 16       17       978       37
# 17       18       539       27
# 18       19       723       37
# 19       20       313       16
# 20       21      1016       39
# 21       22       348       14
# 22       23       580       20
# 23       24      1125       51
# 24       25       318       18
# 25       26       753       32
# 26       27       365        9
# 27       28       640       33
# 28       29       746       32
# ...

# %%
#  Let's set the minimum threshold to 3% 

def prune_rules_01():
    total_transactions = 830
    min_support_percent = 3
    min_support = total_transactions * min_support_percent / 100
    print(min_support)
    df.drop(df[df['Support'] < min_support].index, inplace = True)

    print(df.shape[0])        
    print(df.to_string())
    
prune_rules_01()
# Out:
# 24.9
# 45
#     Product  Quantity  Support
# 0         1       828       38
# 1         2      1057       44
# 6         7       763       29
# 9        10       742       33
# 10       11       706       38
# 12       13       891       40
# 15       16      1158       43
# 16       17       978       37
# 17       18       539       27
# 18       19       723       37
# 20       21      1016       39
# 23       24      1125       51
# 25       26       753       32
# 27       28       640       33
# 28       29       746       32
# 29       30       612       32
# 30       31      1397       51
# 32       33       755       32
# 34       35       883       36
# 35       36       805       31
# 38       39       793       30
# 39       40      1103       41
# 40       41       981       47
# 41       42       697       30
# 42       43       580       28
# 45       46       548       27
# 50       51       886       39
# 51       52       500       29
# ...

# %%
# n = df.shape[0]
# n = ( n*(n-1) )/2  === 990
x=[]
def calculate_support_02_01():
    df2 = pd.DataFrame({"Product":[x]*990, "Support":[0]*990})

# for i in range(0, 77):
    
#     df.iat[i, 0] = x
    k=0;
    for i in df["Product"]:
        for j in df["Product"]:
            x=[]
            if(i>j):
                x.append(j)
                x.append(i)
                df2.iat[k, 0] = x
                k = k+1;
            
    print(df2.to_string())
    
calculate_support_02_01()

# %%
# Calculate Support
# df = pd.DataFrame({"Product":[0]*78,"Quantity":[0]*78, "Support":[0]*78})

def calculate_support_02_02():
    x=[]
    # for i in range(0, 77):
    #     df.iat[i, 0] = i+1
    i=0
    for list1 in df2["Product"]:
        count = 0
        for  list2 in OrdersDetails1['ProductID']:
            if (list1[0] in list2 and list1[1] in list2):
                count = count + 1
        df2.iat[i, 1] = count
        i = i+1


    # print(df)

    print(df2.to_string())
    #for productid in OrdersDetails['ProductID']:
    
calculate_support_02_02()
# Out:
#       Product  Support
# 12    [7, 13]        4
# 16    [2, 16]        5
# 45    [1, 21]        4
# 64   [19, 24]        4
# 121   [2, 31]        5
# 126  [16, 31]        7
# 143  [17, 33]        5
# 162  [19, 35]        4
# 182  [24, 36]        4
# 210   [1, 40]        4
# 220  [21, 40]        4
# 238  [17, 41]        4
# 289  [28, 43]        4
# 306  [16, 46]        4
# 335  [21, 51]        5
# 341  [31, 51]        5
# 373  [41, 52]        4
# 421  [30, 54]        6
# 451  [31, 55]        4
# 457  [41, 55]        4
# 472  [17, 56]        4
# 497   [2, 59]        5
# 502  [16, 59]        4
# 527  [56, 59]        4
# 528   [1, 60]        4
# 531  [10, 60]        4
# 533  [13, 60]        4
# 534  [16, 60]        6
# 544  [31, 60]        4
# 548  [39, 60]        4
# 549  [40, 60]        4
# 567  [16, 62]        6
# 568  [17, 62]        4
# 591  [55, 62]        5
# 606  [24, 64]        4
# 625  [55, 64]        4
# 652  [41, 65]        4
# 661  [56, 65]        5
# 667   [2, 68]        5
# ...

# %%
#  Let's set the minimum threshold to 3% 

def prune_rules_02():
    total_transactions = 830
    # min_support_percent = 3
    min_support = total_transactions * min_support_percent / 100
    print(min_support)
    # df.drop(df[df['Support'] < min_support].index, inplace = True)
    df2.drop(df2[df2['Support'] < 4].index, inplace = True)

    print(df2.shape[0])        
    print(df2.to_string())

# %%
n = df2.shape[0]
x = []
# df3 = pd.DataFrame({"Product":[0]*52, "Support":[0]*52})
df3 = pd.DataFrame({"Product":[x]*104, "Support":[0]*104})
i=0
for list1 in df2["Product"]:
    if list1[0] not in x:
#         df3.iat[i, 0] = list1[0]
        x.append(list1[0])
        i=i+1
    if list1[1] not in x:
#         df3.iat[i, 0] = list1[0]
        x.append(list1[1])
        i=i+1
        
    
df3 = pd.DataFrame(x)    
print(df3.shape)
print(df3.to_string)
# Out:
# (38, 1)
# <bound method DataFrame.to_string of      0
# 0    7
# 1   13
# 2    2
# 3   16
# 4    1
# 5   21
# 6   19
# 7   24
# 8   31
# 9   17
# 10  33
# 11  35
# 12  36
# 13  40
# 14  41
# 15  28
# 16  43
# 17  46
# 18  51
# 19  52
# 20  30
# 21  54
# 22  55
# 23  56
# 24  59
# 25  60
# 26  10
# 27  39
# 28  62
# 29  64
# 30  65
# 31  68
# 32  70
# 33  71
# 34  72
# 35  75
# 36  76
# 37  77>

# %%
df2 = pd.DataFrame({"Product":[x]*990, "Support":[0]*990})

# for i in range(0, 77):
    
#     df.iat[i, 0] = x
k=0;
for i in df["Product"]:
    for j in df["Product"]:
        x=[]
        if(i>j):
            x.append(j)
            x.append(i)
            df2.iat[k, 0] = x
            k = k+1;
            
print(df2.to_string())

# %%
# Calculating Support
x=[]
# for i in range(0, 77):
#     df.iat[i, 0] = i+1
i=0
for list1 in df2["Product"]:
    count = 0
    for  list2 in OrdersDetails1['ProductID']:
        if (list1[0] in list2 and list1[1] in list2):
            count = count + 1
    df2.iat[i, 1] = count
    i = i+1


# print(df)

print(df2.to_string())
#for productid in OrdersDetails['ProductID']:
