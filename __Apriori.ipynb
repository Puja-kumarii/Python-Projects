# %%
import numpy as np  
import pandas as pd  
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Now, we will load the Data  
data1 = pd.read_excel('Online Retail.xlsx')  
data1.head()
# Out:
#   InvoiceNo StockCode                                lower  \
# 0    536365    85123A   white hanging heart t-light holder
# 1    536365     71053                  white metal lantern
# 2    536365    84406B       cream cupid hearts coat hanger
# 3    536365    84029G  knitted union flag hot water bottle
# 4    536365    84029E       red woolly hottie white heart.
#
#                            Description  Quantity         InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country
# 0       2.55     17850.0  United Kingdom
# 1       3.39     17850.0  United Kingdom
# 2       2.75     17850.0  United Kingdom
# 3       3.39     17850.0  United Kingdom
# 4       3.39     17850.0  United Kingdom

# %%
# here, we will explore the columns of the data  
data1.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'lower', 'Description', 'Quantity',
#        'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
# Now, we will explore the different regions of transactions  
data1.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
# here, we will strip the extra spaces in the description  
data1['Description'] = data1['Description'].str.strip()  
  
# Now, drop the rows which does not have any invoice number  
data1.dropna(axis = 0, subset = ['InvoiceNo'], inplace = True)  
data1['InvoiceNo'] = data1['InvoiceNo'].astype('str')  
  
# Now, we will drop all transactions which were done on credit  
data1 = data1[~data1['InvoiceNo'].str.contains('C')] 
 
print(data1)
# Out:
#        InvoiceNo StockCode                                lower  \
# 0         536365    85123A   white hanging heart t-light holder
# 1         536365     71053                  white metal lantern
# 2         536365    84406B       cream cupid hearts coat hanger
# 3         536365    84029G  knitted union flag hot water bottle
# 4         536365    84029E       red woolly hottie white heart.
# ...          ...       ...                                  ...
# 541904    581587     22613                                  NaN
# 541905    581587     22899                                  NaN
# 541906    581587     23254                                  NaN
# 541907    581587     23255                                  NaN
# 541908    581587     22138                                  NaN
#
#                                 Description  Quantity         InvoiceDate  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                       WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2            CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4            RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
# ...                                     ...       ...                 ...
# 541904          PACK OF 20 SPACEBOY NAPKINS        12 2011-12-09 12:50:00
# 541905          CHILDREN'S APRON DOLLY GIRL         6 2011-12-09 12:50:00
# 541906         CHILDRENS CUTLERY DOLLY GIRL         4 2011-12-09 12:50:00
# 541907      CHILDRENS CUTLERY CIRCUS PARADE         4 2011-12-09 12:50:00
# 541908         BAKING SET 9 PIECE RETROSPOT         3 2011-12-09 12:50:00
#
#         UnitPrice  CustomerID         Country
# 0            2.55     17850.0  United Kingdom
# 1            3.39     17850.0  United Kingdom
# 2            2.75     17850.0  United Kingdom
# 3            3.39     17850.0  United Kingdom
# 4            3.39     17850.0  United Kingdom
# ...           ...         ...             ...
# 541904       0.85     12680.0          France
# 541905       2.10     12680.0          France
# 541906       4.15     12680.0          France
# 541907       4.15     12680.0          France
# 541908       4.95     12680.0          France
#
# [532621 rows x 9 columns]

# %%
# Transactions done in France  
basket1_France = (data1[data1['Country'] == "France"]  
        .groupby(['InvoiceNo', 'Description'])['Quantity']  
        .sum().unstack().reset_index().fillna(0)  
        .set_index('InvoiceNo'))  
  
# Transactions done in the United Kingdom  
basket1_UK = (data1[data1['Country'] == "United Kingdom"]  
        .groupby(['InvoiceNo', 'Description'])['Quantity']  
        .sum().unstack().reset_index().fillna(0)  
        .set_index('InvoiceNo'))  
  
# Transactions done in Portugal  
basket1_Por = (data1[data1['Country'] == "Portugal"]  
        .groupby(['InvoiceNo', 'Description'])['Quantity']  
        .sum().unstack().reset_index().fillna(0)  
        .set_index('InvoiceNo'))  
  
basket1_Sweden = (data1[data1['Country'] == "Sweden"]  
        .groupby(['InvoiceNo', 'Description'])['Quantity']  
        .sum().unstack().reset_index().fillna(0)  
        .set_index('InvoiceNo'))

# %%
# Here, we will define the hot encoding function   
# for making the data suitable  
# for the concerned libraries  
def hot_encode1(P):  
    if(P<= 0):  
        return 0  
    if(P>= 1):  
        return 1  
  
# Here, we will encode the datasets  
basket1_encoded = basket1_France.applymap(hot_encode1)  
basket1_France = basket1_encoded  
  
basket1_encoded = basket1_UK.applymap(hot_encode1)  
basket1_UK = basket1_encoded  
  
basket1_encoded = basket1_Por.applymap(hot_encode1)  
basket1_Por = basket1_encoded  
  
basket1_encoded = basket1_Sweden.applymap(hot_encode1)  
basket1_Sweden = basket1_encoded

# %% [markdown]
# # # Frequent Items

# %%
apriori(basket1_France,min_support=0.05)
# Out:
# C:\Users\rohit\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#       support                 itemsets
# 0    0.071429                     (35)
# 1    0.096939                     (61)
# 2    0.102041                     (64)
# 3    0.094388                     (65)
# 4    0.068878                     (82)
# ..        ...                      ...
# 190  0.102041        (1267, 1268, 974)
# 191  0.099490       (1248, 1267, 1268)
# 192  0.056122        (64, 65, 61, 974)
# 193  0.053571     (953, 956, 974, 951)
# 194  0.081633  (1248, 1267, 1268, 974)
#
# [195 rows x 2 columns]

# %% [markdown]
# ## Model Training

# %%
# Building the model
frq_items = apriori(basket1_France, min_support = 0.05, use_colnames = True)
# Out:
# C:\Users\rohit\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %% [markdown]
# ## Association rules

# %%
# Collecting the inferred rules in a dataframe
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)

# Convert the confidence column to a float type
rules['confidence_values'] = rules['confidence'].astype(float)

rules.sort_values('confidence', ascending = False)
# Out:
#                                            antecedents  \
# 270  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 258  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 44                        (JUMBO BAG WOODLAND ANIMALS)
# 301  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 300  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# ..                                                 ...
# 96                                           (POSTAGE)
# 225                                          (POSTAGE)
# 263                                          (POSTAGE)
# 36                                           (POSTAGE)
# 26                                           (POSTAGE)
#
#                                            consequents  antecedent support  \
# 270                                          (POSTAGE)            0.053571
# 258                                          (POSTAGE)            0.051020
# 44                                           (POSTAGE)            0.076531
# 301                    (SET/6 RED SPOTTY PAPER PLATES)            0.102041
# 300                      (SET/6 RED SPOTTY PAPER CUPS)            0.102041
# ..                                                 ...                 ...
# 96                                     (PARTY BUNTING)            0.765306
# 225      (LUNCH BAG RED RETROSPOT, LUNCH BAG WOODLAND)            0.765306
# 263  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...            0.765306
# 36                            (JAM MAKING SET PRINTED)            0.765306
# 26                   (CIRCUS PARADE CHILDRENS EGG CUP)            0.765306
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 270            0.765306  0.053571    1.000000  1.306667  0.012573         inf
# 258            0.765306  0.051020    1.000000  1.306667  0.011974         inf
# 44             0.765306  0.076531    1.000000  1.306667  0.017961         inf
# 301            0.127551  0.099490    0.975000  7.644000  0.086474   34.897959
# 300            0.137755  0.099490    0.975000  7.077778  0.085433   34.489796
# ..                  ...       ...         ...       ...       ...         ...
# 96             0.056122  0.051020    0.066667  1.187879  0.008070    1.011297
# 225            0.056122  0.051020    0.066667  1.187879  0.008070    1.011297
# 263            0.051020  0.051020    0.066667  1.306667  0.011974    1.016764
# 36             0.053571  0.051020    0.066667  1.244444  0.010022    1.014031
# 26             0.056122  0.051020    0.066667  1.187879  0.008070    1.011297
#
#      confidence_values
# 270           1.000000
# 258           1.000000
# 44            1.000000
# 301           0.975000
# 300           0.975000
# ..                 ...
# 96            0.066667
# 225           0.066667
# 263           0.066667
# 36            0.066667
# 26            0.066667
#
# [348 rows x 10 columns]

# %% [markdown]
# ## Association rules which have highest confidence

# %%
# Filter the rules by confidence
high_confidence_rules = rules[rules['confidence_values'] > 0.8]

# Print the high confidence rules
for index, row in high_confidence_rules.iterrows():
    print('Rule:', row['antecedents'], '->', row['consequents'])
    print('Confidence:', row['confidence_values'])
# Out:
# Rule: frozenset({'ALARM CLOCK BAKELIKE GREEN'}) -> frozenset({'ALARM CLOCK BAKELIKE RED'})
# Confidence: 0.8157894736842106
# Rule: frozenset({'ALARM CLOCK BAKELIKE RED'}) -> frozenset({'ALARM CLOCK BAKELIKE GREEN'})
# Confidence: 0.8378378378378379
# Rule: frozenset({'ALARM CLOCK BAKELIKE GREEN'}) -> frozenset({'POSTAGE'})
# Confidence: 0.868421052631579
# Rule: frozenset({'ALARM CLOCK BAKELIKE PINK'}) -> frozenset({'POSTAGE'})
# Confidence: 0.875
# Rule: frozenset({'ALARM CLOCK BAKELIKE RED'}) -> frozenset({'POSTAGE'})
# Confidence: 0.918918918918919
# Rule: frozenset({'ASSORTED COLOUR MINI CASES'}) -> frozenset({'POSTAGE'})
# Confidence: 0.925925925925926
# Rule: frozenset({'CHARLOTTE BAG DOLLY GIRL DESIGN'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8846153846153846
# Rule: frozenset({'CHILDRENS APRON SPACEBOY DESIGN'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8076923076923076
# Rule: frozenset({'CHILDRENS CUTLERY DOLLY GIRL'}) -> frozenset({'CHILDRENS CUTLERY SPACEBOY'})
# Confidence: 0.8928571428571429
# Rule: frozenset({'CHILDRENS CUTLERY SPACEBOY'}) -> frozenset({'CHILDRENS CUTLERY DOLLY GIRL'})
# Confidence: 0.925925925925926
# Rule: frozenset({'CIRCUS PARADE CHILDRENS EGG CUP'}) -> frozenset({'POSTAGE'})
# Confidence: 0.9090909090909091
# Rule: frozenset({'COFFEE MUG APPLES DESIGN'}) -> frozenset({'POSTAGE'})
# Confidence: 0.888888888888889
# Rule: frozenset({'GUMBALL COAT RACK'}) -> frozenset({'POSTAGE'})
# Confidence: 0.9565217391304347
# Rule: frozenset({'JAM MAKING SET PRINTED'}) -> frozenset({'POSTAGE'})
# Confidence: 0.9523809523809524
# Rule: frozenset({'JUMBO BAG APPLES'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8846153846153846
# Rule: frozenset({'JUMBO BAG RED RETROSPOT'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8421052631578947
# Rule: frozenset({'JUMBO BAG SPACEBOY DESIGN'}) -> frozenset({'POSTAGE'})
# Confidence: 0.88
# Rule: frozenset({'JUMBO BAG WOODLAND ANIMALS'}) -> frozenset({'POSTAGE'})
# Confidence: 1.0
# Rule: frozenset({'LUNCH BAG APPLE DESIGN'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8367346938775511
# Rule: frozenset({'LUNCH BAG WOODLAND'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8695652173913043
# Rule: frozenset({'LUNCH BOX WITH CUTLERY RETROSPOT'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8035714285714286
# Rule: frozenset({'PACK OF 6 SKULL PAPER PLATES'}) -> frozenset({'PACK OF 6 SKULL PAPER CUPS'})
# Confidence: 0.9090909090909091
# Rule: frozenset({'PACK OF 6 SKULL PAPER CUPS'}) -> frozenset({'POSTAGE'})
# Confidence: 0.96
# Rule: frozenset({'PACK OF 6 SKULL PAPER PLATES'}) -> frozenset({'POSTAGE'})
# Confidence: 0.9545454545454545
# Rule: frozenset({'PACK OF 72 RETROSPOT CAKE CASES'}) -> frozenset({'POSTAGE'})
# Confidence: 0.825
# Rule: frozenset({'PAPER BUNTING RETROSPOT'}) -> frozenset({'POSTAGE'})
# Confidence: 0.875
# Rule: frozenset({'PARTY BUNTING'}) -> frozenset({'POSTAGE'})
# Confidence: 0.9090909090909091
# Rule: frozenset({'PLASTERS IN TIN CIRCUS PARADE'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8787878787878788
# Rule: frozenset({'PLASTERS IN TIN SPACEBOY'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8333333333333335
# Rule: frozenset({'PLASTERS IN TIN WOODLAND ANIMALS'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8059701492537313
# Rule: frozenset({'RABBIT NIGHT LIGHT'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8783783783783784
# Rule: frozenset({'RED RETROSPOT CHARLOTTE BAG'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8421052631578947
# Rule: frozenset({'RED RETROSPOT MINI CASES'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8333333333333335
# Rule: frozenset({'RED RETROSPOT PICNIC BAG'}) -> frozenset({'POSTAGE'})
# Confidence: 0.9642857142857142
# Rule: frozenset({'RED TOADSTOOL LED NIGHT LIGHT'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8732394366197184
# Rule: frozenset({'REGENCY CAKESTAND 3 TIER'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8367346938775511
# Rule: frozenset({'RETROSPOT PARTY BAG + STICKER SET'}) -> frozenset({'POSTAGE'})
# Confidence: 0.9583333333333334
# Rule: frozenset({'ROUND SNACK BOXES SET OF 4 FRUITS'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8809523809523809
# Rule: frozenset({'ROUND SNACK BOXES SET OF4 WOODLAND'}) -> frozenset({'POSTAGE'})
# Confidence: 0.9354838709677419
# Rule: frozenset({'SET OF 2 TEA TOWELS APPLE AND PEARS'}) -> frozenset({'POSTAGE'})
# Confidence: 0.925925925925926
# Rule: frozenset({'SET OF 9 BLACK SKULL BALLOONS'}) -> frozenset({'POSTAGE'})
# Confidence: 0.9615384615384615
# Rule: frozenset({'SET OF 9 HEART SHAPED BALLOONS'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8461538461538461
# Rule: frozenset({'SET/10 RED POLKADOT PARTY CANDLES'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8333333333333334
# Rule: frozenset({'SET/20 RED RETROSPOT PAPER NAPKINS'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8269230769230769
# Rule: frozenset({'SET/6 RED SPOTTY PAPER CUPS'}) -> frozenset({'POSTAGE'})
# Confidence: 0.851851851851852
# Rule: frozenset({'SET/6 RED SPOTTY PAPER PLATES'}) -> frozenset({'POSTAGE'})
# Confidence: 0.84
# Rule: frozenset({'STRAWBERRY LUNCH BOX WITH CUTLERY'}) -> frozenset({'POSTAGE'})
# Confidence: 0.9375
# Rule: frozenset({'TEA PARTY BIRTHDAY CARD'}) -> frozenset({'POSTAGE'})
# Confidence: 0.945945945945946
# Rule: frozenset({'WOODLAND CHARLOTTE BAG'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8965517241379312
# Rule: frozenset({'SET/6 RED SPOTTY PAPER PLATES'}) -> frozenset({'SET/6 RED SPOTTY PAPER CUPS'})
# Confidence: 0.96
# Rule: frozenset({'SET/6 RED SPOTTY PAPER CUPS'}) -> frozenset({'SET/6 RED SPOTTY PAPER PLATES'})
# Confidence: 0.888888888888889
# Rule: frozenset({'ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE GREEN'}) -> frozenset({'ALARM CLOCK BAKELIKE RED'})
# Confidence: 0.8620689655172414
# Rule: frozenset({'ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE RED'}) -> frozenset({'ALARM CLOCK BAKELIKE GREEN'})
# Confidence: 0.8620689655172414
# Rule: frozenset({'ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE RED'}) -> frozenset({'ALARM CLOCK BAKELIKE PINK'})
# Confidence: 0.8064516129032258
# Rule: frozenset({'ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE GREEN'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8275862068965517
# Rule: frozenset({'ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE RED'}) -> frozenset({'POSTAGE'})
# Confidence: 0.9032258064516128
# Rule: frozenset({'ALARM CLOCK BAKELIKE GREEN', 'POSTAGE'}) -> frozenset({'ALARM CLOCK BAKELIKE RED'})
# Confidence: 0.8484848484848485
# Rule: frozenset({'ALARM CLOCK BAKELIKE RED', 'POSTAGE'}) -> frozenset({'ALARM CLOCK BAKELIKE GREEN'})
# Confidence: 0.8235294117647058
# Rule: frozenset({'ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE RED'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8965517241379312
# Rule: frozenset({'LUNCH BAG APPLE DESIGN', 'LUNCH BAG RED RETROSPOT'}) -> frozenset({'POSTAGE'})
# Confidence: 0.923076923076923
# Rule: frozenset({'LUNCH BAG RED RETROSPOT', 'LUNCH BAG SPACEBOY DESIGN'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8076923076923076
# Rule: frozenset({'LUNCH BAG RED RETROSPOT', 'LUNCH BAG WOODLAND'}) -> frozenset({'POSTAGE'})
# Confidence: 0.9090909090909091
# Rule: frozenset({'LUNCH BAG SPACEBOY DESIGN', 'LUNCH BAG WOODLAND'}) -> frozenset({'POSTAGE'})
# Confidence: 0.84
# Rule: frozenset({'STRAWBERRY LUNCH BOX WITH CUTLERY', 'LUNCH BOX WITH CUTLERY RETROSPOT'}) -> frozenset({'POSTAGE'})
# Confidence: 0.92
# Rule: frozenset({'PLASTERS IN TIN CIRCUS PARADE', 'PLASTERS IN TIN SPACEBOY'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8285714285714285
# Rule: frozenset({'PLASTERS IN TIN WOODLAND ANIMALS', 'PLASTERS IN TIN CIRCUS PARADE'}) -> frozenset({'POSTAGE'})
# Confidence: 0.825
# Rule: frozenset({'RED TOADSTOOL LED NIGHT LIGHT', 'PLASTERS IN TIN CIRCUS PARADE'}) -> frozenset({'POSTAGE'})
# Confidence: 1.0
# Rule: frozenset({'PLASTERS IN TIN WOODLAND ANIMALS', 'PLASTERS IN TIN SPACEBOY'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8048780487804877
# Rule: frozenset({'RED TOADSTOOL LED NIGHT LIGHT', 'PLASTERS IN TIN WOODLAND ANIMALS'}) -> frozenset({'POSTAGE'})
# Confidence: 1.0
# Rule: frozenset({'ROUND SNACK BOXES SET OF 4 FRUITS', 'ROUND SNACK BOXES SET OF4 WOODLAND'}) -> frozenset({'POSTAGE'})
# Confidence: 0.92
# Rule: frozenset({'SET/20 RED RETROSPOT PAPER NAPKINS', 'SET/6 RED SPOTTY PAPER CUPS'}) -> frozenset({'POSTAGE'})
# Confidence: 0.825
# Rule: frozenset({'SET/20 RED RETROSPOT PAPER NAPKINS', 'SET/6 RED SPOTTY PAPER PLATES'}) -> frozenset({'POSTAGE'})
# Confidence: 0.825
# Rule: frozenset({'SET/6 RED SPOTTY PAPER PLATES', 'POSTAGE'}) -> frozenset({'SET/6 RED SPOTTY PAPER CUPS'})
# Confidence: 0.9523809523809524
# Rule: frozenset({'POSTAGE', 'SET/6 RED SPOTTY PAPER CUPS'}) -> frozenset({'SET/6 RED SPOTTY PAPER PLATES'})
# Confidence: 0.8695652173913043
# Rule: frozenset({'SET/6 RED SPOTTY PAPER PLATES', 'SET/6 RED SPOTTY PAPER CUPS'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8333333333333334
# Rule: frozenset({'SET/20 RED RETROSPOT PAPER NAPKINS', 'SET/6 RED SPOTTY PAPER PLATES'}) -> frozenset({'SET/6 RED SPOTTY PAPER CUPS'})
# Confidence: 0.975
# Rule: frozenset({'SET/20 RED RETROSPOT PAPER NAPKINS', 'SET/6 RED SPOTTY PAPER CUPS'}) -> frozenset({'SET/6 RED SPOTTY PAPER PLATES'})
# Confidence: 0.975
# Rule: frozenset({'SET/6 RED SPOTTY PAPER PLATES', 'SET/6 RED SPOTTY PAPER CUPS'}) -> frozenset({'SET/20 RED RETROSPOT PAPER NAPKINS'})
# Confidence: 0.8125
# Rule: frozenset({'ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE RED'}) -> frozenset({'POSTAGE'})
# Confidence: 0.88
# Rule: frozenset({'ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE GREEN', 'POSTAGE'}) -> frozenset({'ALARM CLOCK BAKELIKE RED'})
# Confidence: 0.9166666666666667
# Rule: frozenset({'ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE RED', 'POSTAGE'}) -> frozenset({'ALARM CLOCK BAKELIKE GREEN'})
# Confidence: 0.8461538461538461
# Rule: frozenset({'SET/20 RED RETROSPOT PAPER NAPKINS', 'SET/6 RED SPOTTY PAPER PLATES', 'SET/6 RED SPOTTY PAPER CUPS'}) -> frozenset({'POSTAGE'})
# Confidence: 0.8205128205128205
# Rule: frozenset({'SET/20 RED RETROSPOT PAPER NAPKINS', 'SET/6 RED SPOTTY PAPER PLATES', 'POSTAGE'}) -> frozenset({'SET/6 RED SPOTTY PAPER CUPS'})
# Confidence: 0.9696969696969696
# Rule: frozenset({'SET/20 RED RETROSPOT PAPER NAPKINS', 'POSTAGE', 'SET/6 RED SPOTTY PAPER CUPS'}) -> frozenset({'SET/6 RED SPOTTY PAPER PLATES'})
# Confidence: 0.9696969696969696

# %%
high_confidence_rules.sort_values('confidence', ascending = False)
# Out:
#                                            antecedents  \
# 270  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 258  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 44                        (JUMBO BAG WOODLAND ANIMALS)
# 300  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 301  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# ..                                                 ...
# 23                   (CHILDRENS APRON SPACEBOY DESIGN)
# 178  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# 118                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 265  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
# 78                  (LUNCH BOX WITH CUTLERY RETROSPOT)
#
#                          consequents  antecedent support  consequent support  \
# 270                        (POSTAGE)            0.053571            0.765306
# 258                        (POSTAGE)            0.051020            0.765306
# 44                         (POSTAGE)            0.076531            0.765306
# 300    (SET/6 RED SPOTTY PAPER CUPS)            0.102041            0.137755
# 301  (SET/6 RED SPOTTY PAPER PLATES)            0.102041            0.127551
# ..                               ...                 ...                 ...
# 23                         (POSTAGE)            0.066327            0.765306
# 178      (ALARM CLOCK BAKELIKE PINK)            0.079082            0.102041
# 118                        (POSTAGE)            0.170918            0.765306
# 265                        (POSTAGE)            0.104592            0.765306
# 78                         (POSTAGE)            0.142857            0.765306
#
#       support  confidence      lift  leverage  conviction  confidence_values
# 270  0.053571    1.000000  1.306667  0.012573         inf           1.000000
# 258  0.051020    1.000000  1.306667  0.011974         inf           1.000000
# 44   0.076531    1.000000  1.306667  0.017961         inf           1.000000
# 300  0.099490    0.975000  7.077778  0.085433   34.489796           0.975000
# 301  0.099490    0.975000  7.644000  0.086474   34.897959           0.975000
# ..        ...         ...       ...       ...         ...                ...
# 23   0.053571    0.807692  1.055385  0.002811    1.220408           0.807692
# 178  0.063776    0.806452  7.903226  0.055706    4.639456           0.806452
# 118  0.137755    0.805970  1.053134  0.006950    1.209576           0.805970
# 265  0.084184    0.804878  1.051707  0.004139    1.202806           0.804878
# 78   0.114796    0.803571  1.050000  0.005466    1.194805           0.803571
#
# [84 rows x 10 columns]
